# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("StudentPerformanceFactors.csv")
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.tail()
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 6602           Medium             Yes                  1          High
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
unique_values_all_columns = df.nunique()
print(unique_values_all_columns)
# Out:
# Hours_Studied                 41
# Attendance                    41
# Parental_Involvement           3
# Access_to_Resources            3
# Extracurricular_Activities     2
# Sleep_Hours                    7
# Previous_Scores               51
# Motivation_Level               3
# Internet_Access                2
# Tutoring_Sessions              9
# Family_Income                  3
# Teacher_Quality                3
# School_Type                    2
# Peer_Influence                 3
# Physical_Activity              7
# Learning_Disabilities          2
# Parental_Education_Level       3
# Distance_from_Home             3
# Gender                         2
# Exam_Score                    45
# dtype: int64

# %%
# Yeni dataframe: sayısal veriler
newdf = df.select_dtypes(include='number')

fig, axes = plt.subplots(2, 4, figsize=(15, 10))  # 2 satır, 4 sütun

for i, ax in zip(newdf.columns, axes.flatten()[:7]):
    ax.boxplot(newdf[i])
    ax.set_title(i)

# Boş kalan subplot'ları gizliyoruz
for ax in axes.flatten()[7:]:
    ax.axis('off')

plt.tight_layout()  # Grafikler arasındaki boşlukları düzenler
plt.show()

#Bu kod, her bir sayısal sütun için bir boxplot çizer.Boxplot, verinin dağılımını, merkezi eğilimlerini ve uç değerleri (outliers) görselleştirir. Yani, her bir değişkenin ortalama, medyan, çeyrekler ve uç değerlerinin görsel bir temsilini sağlar.

# %%
fig, ax = plt.subplots()

ax.hist(df['Hours_Studied'], bins=100, color='teal')  #bins(100)=Verileri 100 aralığa böler.Bu,histogramın çözünürlüğünü ayarlar.
ax.spines.right.set_visible(False)  #Histogramın sağ kenarını görünmez yapar.
ax.spines.top.set_visible(False)  #Histogramın üst kenarını görünmez yapar.

# %%
fig, ax = plt.subplots()

ax.hist(df['Attendance'], bins=100, color='green')
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()

ax.hist(df['Sleep_Hours'], bins=20, color='red')
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

ax.set_xlabel('Uyku Saatleri')
ax.set_ylabel('Kişi')
ax.set_title('Uyku Saatlerinin Dağılımı')
# Out:
# Text(0.5, 1.0, 'Uyku Saatlerinin Dağılımı')

# %%
fig, ax = plt.subplots()

ax.hist(df['Previous_Scores'], bins=150, color='brown')
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()

ax.hist(df['Tutoring_Sessions'], bins=41, color='blue')
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()

ax.hist(df['Physical_Activity'], bins=20, color='orange')
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()

ax.hist(df['Exam_Score'], bins=100, color='black')
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()
value_count = df['Parental_Involvement'].value_counts()

ax.pie(value_count, labels=value_count.index, autopct='%1.1f%%', colors=['lightseagreen', 'slateblue', 'lightgray'])
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()
value_count = df['Access_to_Resources'].value_counts()

ax.pie(value_count, labels=value_count.index, autopct='%1.1f%%', colors=['lightseagreen', 'slateblue', 'lightgray'])
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()
value_count = df['Extracurricular_Activities'].value_counts()

ax.pie(value_count, labels=value_count.index, autopct='%1.1f%%', colors=['lightseagreen', 'slateblue', 'lightgray'])
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()
value_count = df['Motivation_Level'].value_counts()

ax.pie(value_count, labels=value_count.index, autopct='%1.1f%%', colors=['lightseagreen', 'slateblue', 'lightgray'])
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()
value_count = df['Internet_Access'].value_counts()

ax.pie(value_count, labels=value_count.index, autopct='%1.1f%%', colors=['lightseagreen', 'slateblue', 'lightgray'])
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()
value_count = df['Family_Income'].value_counts()

ax.pie(value_count, labels=value_count.index, autopct='%1.1f%%', colors=['lightseagreen', 'slateblue', 'lightgray'])
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()
value_count = df['School_Type'].value_counts()

ax.pie(value_count, labels=value_count.index, autopct='%1.1f%%', colors=['lightseagreen', 'slateblue', 'lightgray'])
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()
value_count = df['Peer_Influence'].value_counts()

ax.pie(value_count, labels=value_count.index, autopct='%1.1f%%', colors=['lightseagreen', 'slateblue', 'lightgray'])
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()
value_count = df['Learning_Disabilities'].value_counts()

ax.pie(value_count, labels=value_count.index, autopct='%1.1f%%', colors=['lightseagreen', 'slateblue', 'lightgray'])
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
fig, ax = plt.subplots()
value_count = df['Gender'].value_counts()

ax.pie(value_count, labels=value_count.index, autopct='%1.1f%%', colors=['lightseagreen', 'slateblue', 'lightgray'])
ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

# %%
matrix = newdf.corr(method='spearman')
sns.heatmap(matrix, cmap='Blues', annot=True, fmt=".2f")
plt.show()

# %%
average_scores = df.groupby('Hours_Studied')['Exam_Score'].mean().reset_index()
print(average_scores.head())

plt.figure(figsize=(10, 6))
plt.bar(average_scores['Hours_Studied'], average_scores['Exam_Score'], color='skyblue')
plt.title('Average Exam Score by Hours Studied')
plt.xlabel('Hours Studied')
plt.ylabel('Average Exam Score')

plt.xticks(average_scores['Hours_Studied'], rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

#Bu kod, çalışma saati başına ortalama sınav puanlarını görselleştiren bir bar grafiği oluşturur.X ekseni çalışma saatlerini, Y ekseni ise bu saatlere karşılık gelen ortalama sınav puanlarını gösterir. Grafikte her bir bar, belirli bir çalışma saati aralığındaki ortalama sınav puanını temsil eder.
# Out:
#    Hours_Studied  Exam_Score
# 0              1   71.000000
# 1              2   63.000000
# 2              3   61.333333
# 3              4   61.647059
# 4              5   62.857143

# %%
categorical_columns = df.select_dtypes(include=['object', 'category']).columns

unique_values_freq = {}

for col in categorical_columns:
    unique_values_freq[col] = df[col].value_counts()

for col, freq in unique_values_freq.items():
    print(f"Unique values and frequencies for column '{col}':\n{freq}\n")

# Bu kod, veri setindeki her bir kategorik sütun için benzersiz değerleri ve her bir değerin kaç kez tekrarlandığını ekrana yazdırır. Bu, özellikle kategorik verilerdeki dağılımı anlamak ve verinin yapısını incelemek için faydalıdır.
# Out:
# Unique values and frequencies for column 'Parental_Involvement':
# Parental_Involvement
# Medium    3362
# High      1908
# Low       1337
# Name: count, dtype: int64
#
# Unique values and frequencies for column 'Access_to_Resources':
# Access_to_Resources
# Medium    3319
# High      1975
# Low       1313
# Name: count, dtype: int64
#
# Unique values and frequencies for column 'Extracurricular_Activities':
# Extracurricular_Activities
# Yes    3938
# No     2669
# Name: count, dtype: int64
#
# Unique values and frequencies for column 'Motivation_Level':
# Motivation_Level
# Medium    3351
# Low       1937
# High      1319
# Name: count, dtype: int64
#
# Unique values and frequencies for column 'Internet_Access':
# Internet_Access
# Yes    6108
# No      499
# Name: count, dtype: int64
#
# Unique values and frequencies for column 'Family_Income':
# Family_Income
# Low       2672
# Medium    2666
# High      1269
# Name: count, dtype: int64
#
# ...

# %%
n = (len(categorical_columns) + 2) // 3

fig, axes = plt.subplots(n, 3, figsize=(15, n * 5), constrained_layout=True)
axes = axes.flatten()

for i, col in enumerate(categorical_columns):
    sns.countplot(data=df, x=col, ax=axes[i])
    axes[i].set_title(f"{col} distribution")
    axes[i].set_xlabel(col)

for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)
    
plt.show()

#Bu kod, veri setindeki her bir kategorik sütun için dağılım grafiği çizer.Kategorik sütundaki her bir benzersiz değerin sıklığını görselleştirir.

# %%
categorical_columns_with_missing = ['Parental_Education_Level', 'Distance_from_Home', 'Teacher_Quality']

for column in categorical_columns_with_missing:
    mode_value = df[column].mode()[0]  
    df.fillna({column: mode_value}, inplace=True)
df.sample(5)

#Bu kod, belirtilen kategorik sütunlardaki eksik değerleri, her sütunun en sık görülen değeri (mod) ile doldurur ve ardından veri çerçevesinin güncellenmiş halinden 5 rastgele satır örneği gösterir.
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 4260             26          76               Medium              Medium
# 258              23          89                  Low                 Low
# 2732             23          75                 High              Medium
# 2980             22          97                  Low              Medium
# 3319             34          84               Medium                High
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 4260                         No            7               59
# 258                         Yes            7               56
# 2732                         No            8               87
# 2980                         No            8               75
# 3319                        Yes            6               95
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 4260              Low             Yes                  0        Medium
# ...

# %%
categorical_columns = [
    'Parental_Involvement', 'Access_to_Resources', 'Extracurricular_Activities', 
    'Motivation_Level', 'Internet_Access', 'Family_Income','Teacher_Quality', 'School_Type', 
    'Peer_Influence', 'Learning_Disabilities', 'Parental_Education_Level','Distance_from_Home','Gender'
]

df = pd.get_dummies(df, columns=categorical_columns, drop_first=True)
df.sample(5)

#Bu kod, kategorik değerleri One-Hot Encoding yöntemiyle dönüştürür.Bu işlem, kategorik sütunlardaki her bir benzersiz değeri ayrı bir sütun olarak ele alır ve bu sütunlara 1 ve 0 değerlerini atar.
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 1165             35          93            6               94
# 1409             18          97            8               66
# 342              21          70            4               94
# 334              26          95            7               77
# 5732             26          86            7               65
#
#       Tutoring_Sessions  Physical_Activity  Exam_Score  \
# 1165                  5                  2          76
# 1409                  2                  2          70
# 342                   0                  2          65
# 334                   0                  3          70
# 5732                  2                  4          71
#
#       Parental_Involvement_Low  Parental_Involvement_Medium  \
# 1165                     False                         True
# 1409                     False                         True
# 342                       True                        False
# ...

# %%
z = np.abs((df - df.mean()) / df.std())
threshold = 3
df= df[(z < threshold).all(axis=1)]

#Bu kod, veri setindeki her bir sayısal sütun için Z-score değerlerini hesaplar ve bu değerlerin belirli bir eşik değerinden büyük olup olmadığını kontrol eder. Eşik değeri genellikle 3 olarak belirlenir. Eğer bir veri noktasının Z-score değeri 3'ten büyükse, bu veri noktası uç değer olarak kabul edilir ve veri setinden çıkarılır.

# %%
df_corr = df.corr()
plt.figure(figsize = (15, 10))
sns.heatmap(df_corr, fmt = ".2f", annot = True, cmap = "Blues")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, accuracy_score
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
X = df.drop("Exam_Score",axis=1)
y = df[["Exam_Score"]]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
y_train = y_train.squeeze()
y_test = y_test.squeeze()

#Eğer y_train bir numpy array ve şekli (n, 1) (n örnek, 1 hedef değişken) ise, y_train.squeeze() bu diziyi (n,) şeklinde dönüştürür. Aynısı y_test için de geçerlidir.

# %%
from sklearn.tree import DecisionTreeRegressor

dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X_train, y_train)

y_pred = dt_model.predict(X_test)

print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100 }")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Mean Squared Error (MSE): 3.388734995383195
# Root Mean Squared Error (RMSE): 1.8408517037999543
# Mean Absolute Error (MAE): 1.4367497691597415
# Mean Absolute Percentage Error (MAPE): 2.1485009114803626
# R^2 Score: 0.6796555253761899

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2']
}

grid_search = GridSearchCV(DecisionTreeRegressor(random_state=42), param_grid, cv=5, scoring='r2', n_jobs=-1)
grid_search.fit(X_train, y_train)

print("En iyi parametreler:", grid_search.best_params_)
best_dt_model = grid_search.best_estimator_

y_pred = best_dt_model.predict(X_test)

print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100 }")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# En iyi parametreler: {'max_depth': 10, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Mean Squared Error (MSE): 2.801682111736126
# Root Mean Squared Error (RMSE): 1.6738226046197746
# Mean Absolute Error (MAE): 1.334299118072208
# Mean Absolute Percentage Error (MAPE): 1.9951637255150054
# R^2 Score: 0.7351509087108337

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb_model = GradientBoostingRegressor(random_state=42, n_estimators=100, learning_rate=0.1, max_depth=3)
gb_model.fit(X_train, y_train)

y_pred = gb_model.predict(X_test)

print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100}")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Mean Squared Error (MSE): 0.5525686765766858
# Root Mean Squared Error (RMSE): 0.743349632795151
# Mean Absolute Error (MAE): 0.5997761716439984
# Mean Absolute Percentage Error (MAPE): 0.8990357125739916
# R^2 Score: 0.9477644836103462

# %%
from sklearn.model_selection import GridSearchCV

# Gradient Boosting Regressor modelini tanımlama
gbr = GradientBoostingRegressor()

# Hiperparametre ızgarasını oluşturma
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 4, 5],
    'subsample': [0.8, 1.0],
    'min_samples_split': [2, 5, 10]
}

# GridSearchCV tanımlama
grid_search = GridSearchCV(estimator=gbr, param_grid=param_grid, cv=5, scoring='r2', n_jobs=-1, verbose=2)

# GridSearch'i eğitme
grid_search.fit(X_train, y_train)

print("En iyi parametreler:", grid_search.best_params_)
print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100}")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# En iyi parametreler: {'learning_rate': 0.1, 'max_depth': 3, 'min_samples_split': 10, 'n_estimators': 300, 'subsample': 0.8}
# Mean Squared Error (MSE): 0.5525686765766858
# Root Mean Squared Error (RMSE): 0.743349632795151
# Mean Absolute Error (MAE): 0.5997761716439984
# Mean Absolute Percentage Error (MAPE): 0.8990357125739916
# R^2 Score: 0.9477644836103462

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor(random_state=42, n_estimators=100, learning_rate=0.1, max_depth=3)
xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100}")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Mean Squared Error (MSE): 0.5469998717308044
# Root Mean Squared Error (RMSE): 0.7395943967681234
# Mean Absolute Error (MAE): 0.5938327312469482
# Mean Absolute Percentage Error (MAPE): 0.8894794605978248
# R^2 Score: 0.9482909440994263

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X_train,y_train)

y_pred = reg.predict(X_test)

print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100}")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Mean Squared Error (MSE): 0.10267313553028197
# Root Mean Squared Error (RMSE): 0.32042649005705187
# Mean Absolute Error (MAE): 0.26610727378022764
# Mean Absolute Percentage Error (MAPE): 0.3978319669543105
# R^2 Score: 0.9902940856383761

# %%
from sklearn.model_selection import GridSearchCV

# Lineer Regresyon modelini oluştur
model = LinearRegression()

# Parametre gridini tanımla
param_grid = {
    'fit_intercept': [True, False],  # Kesme teriminin olup olmayacağını seç
    'copy_X': [True, False],         # X'in kopyalanıp kopyalanmayacağı
    'n_jobs': [None, -1],            # İşlemci sayısı
    'positive': [True, False],       # Pozitif tahminler olup olacağı
}
# GridSearchCV'yi oluştur ve veriyi kullanarak modele uygulama yap
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')

# Modeli eğit
grid_search.fit(X_train, y_train)

# En iyi parametreleri ve model performansını yazdır
print("En iyi parametreler:", grid_search.best_params_)

# Test verisi ile modelin başarımını değerlendir
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100}")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# En iyi parametreler: {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}
# Mean Squared Error (MSE): 0.10267313553028197
# Root Mean Squared Error (RMSE): 0.32042649005705187
# Mean Absolute Error (MAE): 0.26610727378022764
# Mean Absolute Percentage Error (MAPE): 0.3978319669543105
# R^2 Score: 0.9902940856383761

# %%
from sklearn.neighbors import KNeighborsRegressor

# KNN modelini oluşturma
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, y_train)

# Modelin tahmin yapması
y_pred = knn.predict(X_test)

print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100}")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Mean Squared Error (MSE): 2.159187442289935
# Root Mean Squared Error (RMSE): 1.469417381920445
# Mean Absolute Error (MAE): 1.1782086795937214
# Mean Absolute Percentage Error (MAPE): 1.765573039069843
# R^2 Score: 0.7958873243977337

# %%
from sklearn.model_selection import GridSearchCV

# KNN Regressor için hiperparametre arama aralığı
param_grid = {
    'n_neighbors': [3, 5, 7, 10],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

# KNN Regressor ve GridSearchCV tanımlaması
knn_regressor = KNeighborsRegressor()
grid_search = GridSearchCV(estimator=knn_regressor, param_grid=param_grid, 
                           cv=5, scoring='r2', verbose=2, n_jobs=-1)

# GridSearch ile modeli eğitiyoruz
grid_search.fit(X_train, y_train)

# En iyi hiperparametreleri yazdırıyoruz
print("Best Parameters:", grid_search.best_params_)

# En iyi model ile test verisini tahmin ediyoruz
best_knn = grid_search.best_estimator_
y_pred = best_knn.predict(X_test)

print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100}")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'distance'}
# Mean Squared Error (MSE): 1.8172527439341428
# Root Mean Squared Error (RMSE): 1.3480551709533786
# Mean Absolute Error (MAE): 1.0886949658923355
# Mean Absolute Percentage Error (MAPE): 1.635804609091223
# R^2 Score: 0.8282111536288981

# %%
from sklearn.svm import SVR

# SVM Regressor modelini oluşturuyoruz
svm_regressor = SVR()

# Modeli eğitiyoruz
svm_regressor.fit(X_train, y_train)

# Test verisi ile tahmin yapıyoruz
y_pred = svm_regressor.predict(X_test)

print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100}")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Mean Squared Error (MSE): 1.8418422648988386
# Root Mean Squared Error (RMSE): 1.3571448945852609
# Mean Absolute Error (MAE): 1.1007195300889534
# Mean Absolute Percentage Error (MAPE): 1.64952934583526
# R^2 Score: 0.8258866528386568

# %%
from sklearn.model_selection import GridSearchCV

# SVM Regressor modelini oluşturuyoruz
svm_regressor = SVR()

# GridSearchCV için parametreler
param_grid = {
    'C': [0.1, 1, 10],                   # Regularization parametresi
    'epsilon': [0.01, 0.1, 0.2],         # Hata payı
    'kernel': ['linear', 'rbf', 'poly']  # Kernel türleri
}

# GridSearchCV nesnesini oluşturuyoruz
grid_search = GridSearchCV(estimator=svm_regressor, param_grid=param_grid, 
                           cv=3, scoring='r2', n_jobs=-1, verbose=2)

# GridSearchCV ile modelin parametrelerini arıyoruz
grid_search.fit(X_train, y_train)

print("En iyi parametreler:", grid_search.best_params_)

best_model = grid_search.best_estimator_

y_pred = best_model.predict(X_test)

print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100}")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# En iyi parametreler: {'C': 10, 'epsilon': 0.2, 'kernel': 'linear'}
# Mean Squared Error (MSE): 0.1020516161082076
# Root Mean Squared Error (RMSE): 0.31945518638489434
# Mean Absolute Error (MAE): 0.2651326656690106
# Mean Absolute Percentage Error (MAPE): 0.39625926035748654
# R^2 Score: 0.9903528392184004

# %%
from sklearn.ensemble import RandomForestRegressor

rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Modeli eğitiyoruz
rf_regressor.fit(X_train, y_train)

# Test verisi ile tahmin yapıyoruz
y_pred = rf_regressor.predict(X_test)

print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100}")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Mean Squared Error (MSE): 1.2411828254847646
# Root Mean Squared Error (RMSE): 1.1140838502934887
# Mean Absolute Error (MAE): 0.9071837488457988
# Mean Absolute Percentage Error (MAPE): 1.3582225803902197
# R^2 Score: 0.8826682934240326

# %%
from sklearn.model_selection import GridSearchCV

#Hiperparametre optimizasyonu için parametreler
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# GridSearchCV ile hiperparametre araması
grid_search = GridSearchCV(
    estimator=RandomForestRegressor(random_state=42),
    param_grid=param_grid,
    cv=10,
    scoring='r2',
    verbose=1,
    n_jobs=-1
)

grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

print(f"Mean Squared Error (MSE): {mean_squared_error(y_test, y_pred)}")
print(f"Root Mean Squared Error (RMSE): {np.sqrt(mean_squared_error(y_test, y_pred))}")
print(f"Mean Absolute Error (MAE): {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Absolute Percentage Error (MAPE): {np.mean(np.abs((y_test - y_pred) / y_test)) * 100}")
print(f"R^2 Score: {r2_score(y_test, y_pred)}")
# Out:
# Fitting 10 folds for each of 81 candidates, totalling 810 fits
# Mean Squared Error (MSE): 1.2411828254847646
# Root Mean Squared Error (RMSE): 1.1140838502934887
# Mean Absolute Error (MAE): 0.9071837488457988
# Mean Absolute Percentage Error (MAPE): 1.3582225803902197
# R^2 Score: 0.8826682934240326

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler

# Yeni öğrenci verisini alma fonksiyonu
def get_student_data():
    try:
        print("LÜTFEN YENİ ÖĞRENCİ İÇİN İSTENEN DEĞERLERİ GİRİNİZ:")
        student_data = {
            'Hours_Studied': float(input("Çalışma Saati: ")),
            'Attendance': int(input("Derse Katılım(%): ")),
            'Parental_Involvement': int(input("Ebeveyn Katılımı (0:Düşük, 1:Orta, 2:Yüksek): ")),
            'Access_to_Resources': int(input("Eğitim Kaynaklarına Erişim (0:Düşük, 1:Orta, 2:Yüksek): ")),
            'Extracurricular_Activities': int(input("Ders Dışı Aktivite (0:Hayır, 1:Evet): ")),
            'Sleep_Hours': float(input("Uyku Saati: ")),
            'Previous_Scores': float(input("Önceki Not: ")),
            'Motivation_Level': int(input("Motivasyon Seviyesi (0:Düşük, 1:Orta, 2:Yüksek): ")),
            'Internet_Access': int(input("Internet Erişimi (0:Hayır, 1:Evet): ")),
            'Tutoring_Sessions': int(input("Aylık Katılım Sağlanan Özel Ders Sayısı: ")),
            'Family_Income': int(input("Ailenin Gelir Düzeyi (0:Düşük, 1:Orta, 2:Yüksek): ")),
            'Teacher_Quality': int(input("Öğretmen Kalitesi (0:Düşük, 1:Orta, 2:Yüksek): ")),
            'School_Type': int(input("Okul Türü (0: Devlet, 1: Özel): ")),
            'Peer_Influence': int(input("Akran Etkisi (0:Negatif, 1:Nötr, 2:Pozitif): ")),
            'Physical_Activity': int(input("Haftada Ortalama Fiziksel Aktivite Saati: ")),
            'Learning_Disabilities': int(input("Öğrenme Güçlüğü (0:Yok, 1:Var): ")),
            'Parental_Education_Level': int(input("Ebeveyn Eğitim Seviyesi (0:Lise, 1:Lisans, 2:Lisansüstü): ")),
            'Distance_from_Home': int(input("Ev ve Okul Arası Uzaklık (0:Yakın, 1:Orta, 2:Uzak): ")),
            'Gender': int(input("Cinsiyet (0:Kadın, 1:Erkek): "))
        }
        return pd.DataFrame([student_data])
    except ValueError:
        print("Hatalı giriş yaptınız. Lütfen tüm girdilerin doğru formatta olduğundan emin olun.")
        return None

# Model eğitimi ve tahmin için ön hazırlık
scaler = StandardScaler()
rf_model = RandomForestRegressor(random_state=42, n_estimators=100, max_depth=10)

# Eğitim verisini ölçeklendirmek
X_train_encoded = X_train
X_train_scaled = scaler.fit_transform(X_train_encoded)
rf_model.fit(X_train_scaled, y_train)

# Yeni öğrenci tahmini ve çalışma planı oluşturma
new_student_data = get_student_data()
if new_student_data is not None:
    # Eğitim setindeki sütunlarla uyumlu hale getirme
    for col in X_train_encoded.columns:
        if col not in new_student_data.columns:
            new_student_data[col] = 0

    new_student_scaled = scaler.transform(new_student_data[X_train_encoded.columns])
    predicted_score = rf_model.predict(new_student_scaled)[0]

    # Sonucu yazdırma
    print(f"\nYeni Öğrenci İçin Tahmini Not: {predicted_score:.2f}")
# Out:
# LÜTFEN YENİ ÖĞRENCİ İÇİN İSTENEN DEĞERLERİ GİRİNİZ:
#
# Yeni Öğrenci İçin Tahmini Not: 68.23
